# %% [markdown]
# **Scenario: Setting Up a Garment Store**
#
# Your friend is embarking on the journey of setting up a garment store. Launching a new business with limited funds demands meticulous planning, resourcefulness, and a sharp understanding of the market. For the initial phase, your friend has decided to focus solely on one product - Jeans, and is investing 100,000 INR in inventory.

# %% [markdown]
# **TASK - Data Driven Budget Allocation**
#
# Let's assume you with the help of an expert got the following information about jeans size and height ranges for both the genders. Consider the following chart for better Budget Allocation.

# %% [markdown]
# **Your Task:** Give a proper budget allocation to your friend based on your data analysis skills.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("height_gender_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      height  gender
# 0           0  142.905550    Male
# 1           1  115.598717    Male
# 2           2  138.027187  Female
# 3           3  130.939245    Male
# 4           4  125.079458  Female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10000 non-null  int64
#  1   height      10000 non-null  float64
#  2   gender      10000 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 234.5+ KB

# %%
df.drop(["Unnamed: 0"], axis =1, inplace =True)

# %%
df.head()
# Out:
#        height  gender
# 0  142.905550    Male
# 1  115.598717    Male
# 2  138.027187  Female
# 3  130.939245    Male
# 4  125.079458  Female

# %% [markdown]
# # Univariate

# %%
df["gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["gender"].nunique()
# Out:
# 2

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      7114
# Female    2886
# Name: count, dtype: int64

# %% [markdown]
# **From the given data set the Females are nearly 30%. and Males are 70%.**

# %%
grp = df.groupby("gender")

# %%
grp["height"].mean()
# Out:
# gender
# Female    145.116418
# Male      145.019193
# Name: height, dtype: float64

# %%
grp["height"].std()
# Out:
# gender
# Female    14.395899
# Male      15.046135
# Name: height, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(3,3))

ax.set_title("Histogram Plot")
sns.histplot(data=df.loc[df['gender']=="Female"], x='height', alpha=0.3, ax=ax, label="Female")
sns.histplot(data=df.loc[df['gender']=="Male"], x='height', alpha=0.3, ax=ax, label="Male")
ax.legend()

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 3), constrained_layout=True)
fig.suptitle("Numerical Feature Visualization with Seaborn")

axs[0].set_title("Histogram Plot")
sns.histplot(data=df.loc[df['gender']=='Female'], x='height', ax=axs[0], label="Female")
axs[0].legend()

axs[1].set_title("Histogram Plot")
sns.histplot(data=df.loc[df['gender']=='Male'], x='height', ax=axs[1], label="Male")
axs[1].legend()
plt.show()

# %%
def normal_distribution(mean, std, size):
    return np.random.normal(loc=mean, scale=std, size=size)
normal_dist = normal_distribution(mean= 145.02 , std=15.04 , size=7114)

# %%
plt.figure(figsize=(20,10))

sns.histplot(normal_dist)

plt.axvline(normal_dist.mean(), color='coral', label='Mean')
plt.title("68 - 95 - 99.7 Rule for Male ")
plt.axvline(normal_dist.mean() + (1 * normal_dist.std()), color='yellow', label='Mean + 1SD')
plt.axvline(normal_dist.mean() - (1 * normal_dist.std()), color='yellow', label='Mean - 1SD')
plt.axvline(normal_dist.mean() + (2 * normal_dist.std()), color='green', label='Mean + 2SD')
plt.axvline(normal_dist.mean() - (2 * normal_dist.std()), color='green', label='Mean - 2SD')
plt.axvline(normal_dist.mean() + (3 * normal_dist.std()), color='blue', label='Mean + 3SD')
plt.axvline(normal_dist.mean() - (3 * normal_dist.std()), color='blue', label='Mean - 3SD')

plt.legend()

plt.show()

# %%
from IPython.display import Image

Image(filename='C:\\Users\\laxmi\\OneDrive\\Desktop\\butgect_allocation.png')
